# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# Data for the three lines
lg = [0.12, 0, 0, 0, 0.14, 0.09, 0.12, 0.13, 0.07, 
      0, 0.42, 0.09, 0.33, 0.12, 0.15, 0.18, 0.50, 
      0.14, 0.32, 0.15, 0.17, 0.44, 0.18, 0.36, 0.31, 
      0.43, 0.21, 0.38, 0.31, 0.43, 0.45]

rf = [0.12,0,0,0,0.15,0.09,0.12,0.23,0.19,0.00,0.36,0.09,0.21,0.13,0.14,0.14,0.39,
     0.22,0.31,0.2,0.22,0.34,0.16,0.37,0.36,0.34,0.21,0.44,0.34,0.45,0.35]

xg = [0.12, 0, 0, 0, 0.14, 0.09, 0.12, 0.27, 0.19, 
      0.001, 0.34, 0.1, 0.35, 0.14, 0.19, 0.09, 0.29, 
      0.22, 0.35, 0.18, 0.26, 0.31, 0.16, 0.33, 0.33, 0.31, 
      0.35, 0.44, 0.31, 0.41, 0.41]

ann = [0.12,0,0,0,0.15,0.09,0.12,0.26,0,0,0.36,0.11,0.23,0.13,0.13,
      0.13,0.39,0.23,0.44,0.21,0.23,0.31,0.14,0,0,0,
      0.24,0.48,0.45,0.55,0.37]



# Plot the lines
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(range(1, 32), lg, label='Logistic Regression')
ax.plot(range(1, 32), rf, label='Randon Forest')
ax.plot(range(1, 32), xg, label='XGBoost')
ax.plot(range(1, 32), ann, label='ANN')


# Add title and axis labels
ax.set_title('Comparison different models')
ax.set_xlabel('Number of feature-subset')
ax.set_ylabel('TN_score')


plt.xticks(range(1, 32))


# Add a legend
ax.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Define the TN_scores for each model
lg = [0.12, 0, 0, 0, 0.14, 0.09, 0.12, 0.13, 0.07, 0, 0.42, 0.09, 0.33, 0.12, 0.15, 0.18, 0.50,
      0.14, 0.32, 0.15, 0.17, 0.44, 0.18, 0.36, 0.31, 0.43, 0.21, 0.38, 0.31, 0.43, 0.45]

rf = [0.7,0.64,0.7,0.62,0.7,0.63,0.63,0.63,0.58,0.65,0.6,0.71,0.68,0.71,0.65,0.64,0.67,
     0.68,0.64,0.7,0.58,0.65,0.70,0.65,0.67,0.66,0.68,0.68,0.7,0.69,0.69]

xg = [0.12, 0, 0, 0, 0.14, 0.09, 0.12, 0.27, 0.19, 0.001, 0.34, 0.1, 0.35, 0.14, 0.19, 0.09, 0.29,
      0.22, 0.35, 0.18, 0.26, 0.31, 0.16, 0.33, 0.33, 0.31, 0.35, 0.44, 0.31, 0.41, 0.41]

ann = [0.12,0,0,0,0.15,0.09,0.12,0.26,0,0,0.36,0.11,0.23,0.13,0.13, 0.13,0.39,0.23,0.44,0.21,0.23,0.31,0.14,0,0,0,
      0.24,0.48,0.45,0.55,0.37]

# Create a list of the TN_scores for each model
tn_scores = [lg, rf, xg, ann]

# Create a boxplot to compare the distribution of scores between the models
plt.boxplot(tn_scores)
plt.xticks([1, 2, 3, 4], ['lg', 'rf', 'xg', 'ann'])
plt.ylabel('TN_score')
plt.title('Distribution of TN_scores across Models')
plt.show()
